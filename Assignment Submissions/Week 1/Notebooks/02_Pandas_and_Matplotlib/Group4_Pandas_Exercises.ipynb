# %% [markdown]
# # Pandas Exercises

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/BeaverWorksMedlytics2020/Data_Public/master/NotebookExampleData/Week1/diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'diabetes']

# %% [markdown]
# Read in csv above to a pandas dataframe

# %%
df = pd.read_csv(url, names=names)
df
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  diabetes
# 0       6   148    72    35     0  33.6  0.627   50         1
# 1       1    85    66    29     0  26.6  0.351   31         0
# 2       8   183    64     0     0  23.3  0.672   32         1
# 3       1    89    66    23    94  28.1  0.167   21         0
# 4       0   137    40    35   168  43.1  2.288   33         1
# ..    ...   ...   ...   ...   ...   ...    ...  ...       ...
# 763    10   101    76    48   180  32.9  0.171   63         0
# 764     2   122    70    27     0  36.8  0.340   27         0
# 765     5   121    72    23   112  26.2  0.245   30         0
# 766     1   126    60     0     0  30.1  0.349   47         1
# 767     1    93    70    31     0  30.4  0.315   23         0
#
# [768 rows x 9 columns]

# %% [markdown]
# Print out the age and class of the 100th patient

# %%
df.iloc[99,7:]
# Out:
# age         31.0
# diabetes     1.0
# Name: 99, dtype: float64

# %% [markdown]
# Write code to figure out how many people are classified as not having diabetes, class is 0 (500)

# %%
df_no_diabetes = df[df.diabetes == 0]

df_no_diabetes
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  diabetes
# 1       1    85    66    29     0  26.6  0.351   31         0
# 3       1    89    66    23    94  28.1  0.167   21         0
# 5       5   116    74     0     0  25.6  0.201   30         0
# 7      10   115     0     0     0  35.3  0.134   29         0
# 10      4   110    92     0     0  37.6  0.191   30         0
# ..    ...   ...   ...   ...   ...   ...    ...  ...       ...
# 762     9    89    62     0     0  22.5  0.142   33         0
# 763    10   101    76    48   180  32.9  0.171   63         0
# 764     2   122    70    27     0  36.8  0.340   27         0
# 765     5   121    72    23   112  26.2  0.245   30         0
# 767     1    93    70    31     0  30.4  0.315   23         0
#
# [500 rows x 9 columns]

# %% [markdown]
# Write code to figure out how many people are classified as having diabetes, class is 1 (268)

# %%
df_diabetes = df[df.diabetes == 1]

df_diabetes
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  diabetes
# 0       6   148    72    35     0  33.6  0.627   50         1
# 2       8   183    64     0     0  23.3  0.672   32         1
# 4       0   137    40    35   168  43.1  2.288   33         1
# 6       3    78    50    32    88  31.0  0.248   26         1
# 8       2   197    70    45   543  30.5  0.158   53         1
# ..    ...   ...   ...   ...   ...   ...    ...  ...       ...
# 755     1   128    88    39   110  36.5  1.057   37         1
# 757     0   123    72     0     0  36.3  0.258   52         1
# 759     6   190    92     0     0  35.5  0.278   66         1
# 761     9   170    74    31     0  44.0  0.403   43         1
# 766     1   126    60     0     0  30.1  0.349   47         1
#
# [268 rows x 9 columns]

# %% [markdown]
# What percent of people have diabetes in the study

# %%
print((df_diabetes.count()/df.count())*100)
# Out:
# preg        34.895833
# plas        34.895833
# pres        34.895833
# skin        34.895833
# test        34.895833
# mass        34.895833
# pedi        34.895833
# age         34.895833
# diabetes    34.895833
# dtype: float64

# %% [markdown]
# Print out the `"pres"` and `"class"` (no other columns) for the first 5 people

# %%
df.loc[0:4, ["pres","diabetes"]]
# Out:
#    pres  diabetes
# 0    72         1
# 1    66         0
# 2    64         1
# 3    66         0
# 4    40         1

# %% [markdown]
# Run the cell below, it will print out the correlation among the columns

# %%
data = df
data.corr()
# Out:
#               preg      plas      pres      skin      test      mass  \
# preg      1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683
# plas      0.129459  1.000000  0.152590  0.057328  0.331357  0.221071
# pres      0.141282  0.152590  1.000000  0.207371  0.088933  0.281805
# skin     -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573
# test     -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859
# mass      0.017683  0.221071  0.281805  0.392573  0.197859  1.000000
# pedi     -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647
# age       0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242
# diabetes  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695
#
#               pedi       age  diabetes
# preg     -0.033523  0.544341  0.221898
# plas      0.137337  0.263514  0.466581
# pres      0.041265  0.239528  0.065068
# skin      0.183928 -0.113970  0.074752
# test      0.185071 -0.042163  0.130548
# mass      0.140647  0.036242  0.292695
# pedi      1.000000  0.033561  0.173844
# age       0.033561  1.000000  0.238356
# diabetes  0.173844  0.238356  1.000000

# %% [markdown]
# What column has the highest correlation with class? Find the mean() value of that column

# %%
plas_mean = df["plas"].mean()

# %% [markdown]
# Create a new dataframe with only people that are above the mean found in the above cell.

# %%
df_above_plas_mean = df[df["plas"]>plas_mean]
df_above_plas_mean
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  diabetes
# 0       6   148    72    35     0  33.6  0.627   50         1
# 2       8   183    64     0     0  23.3  0.672   32         1
# 4       0   137    40    35   168  43.1  2.288   33         1
# 8       2   197    70    45   543  30.5  0.158   53         1
# 9       8   125    96     0     0   0.0  0.232   54         1
# ..    ...   ...   ...   ...   ...   ...    ...  ...       ...
# 759     6   190    92     0     0  35.5  0.278   66         1
# 761     9   170    74    31     0  44.0  0.403   43         1
# 764     2   122    70    27     0  36.8  0.340   27         0
# 765     5   121    72    23   112  26.2  0.245   30         0
# 766     1   126    60     0     0  30.1  0.349   47         1
#
# [349 rows x 9 columns]

# %% [markdown]
# Create a new dataframe that only includes people who are above the average value for each column in the dataset. In other words, find the average value for each column, and then find which users have values above all of these average column values.

# %%
preg_mean = df["preg"].mean()
pres_mean = df["pres"].mean()
skin_mean = df["skin"].mean()
test_mean = df["test"].mean()
mass_mean = df["mass"].mean()
pedi_mean = df["pedi"].mean()
age_mean = df["age"].mean()

df_above_mean = df[(df["plas"] > plas_mean) &(df["preg"] > preg_mean) &(df["skin"] > skin_mean) &(df["test"] > test_mean) &(df["mass"] > mass_mean) &(df["pedi"] > pedi_mean) &(df["age"] > age_mean) &(df["pres"] > pres_mean)]

df_above_mean
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  diabetes
# 43      9   171   110    24   240  45.4  0.721   54         1
# 152     9   156    86    28   155  34.3  1.189   42         1
# 159    17   163    72    41   114  40.9  0.817   47         1
# 175     8   179    72    42   130  32.7  0.719   36         1
# 206     8   196    76    29   280  37.5  0.605   57         1
# 215    12   151    70    40   271  41.8  0.742   38         1
# 236     7   181    84    21   192  35.9  0.586   51         1
# 259    11   155    76    28   150  33.3  1.353   51         1
# 286     5   155    84    44   545  38.7  0.619   34         0
# 375    12   140    82    43   325  39.2  0.528   58         1
# 424     8   151    78    32   210  42.9  0.516   36         1
# 458    10   148    84    48   237  37.6  1.001   51         1
# 546     5   187    76    27   207  43.6  1.034   53         1
# 594     6   123    72    45   230  33.6  0.733   34         0
# 603     7   150    78    29   126  35.2  0.692   54         1
# 612     7   168    88    42   321  38.2  0.787   40         1
# 614    11   138    74    26   144  36.1  0.557   50         1
# 663     9   145    80    46   130  37.9  0.637   40         1
# 744    13   153    88    37   140  40.6  1.174   39         0

# %% [markdown]
# *Note: the next 3 problems were not explicitly shown in our tutorial—being able to effectively google and look through documentation is a very important coding tool!* ¯\\\_(ツ)_/¯

# %% [markdown]
# Ignoring the index (resetting the index to 0) and using the dataframe from the cell above, sort the values based on `"skin"`, `"test"`, and `"pedi"` values in ascending order. Please write this in one line.

# %%
df.sort_values(["skin","test","pedi"], ascending=True)
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  diabetes
# 268     0   102    52     0     0  25.1  0.078   21         0
# 180     6    87    80     0     0  23.2  0.084   32         0
# 598     1   173    74     0     0  36.8  0.088   38         1
# 81      2    74     0     0     0   0.0  0.102   22         0
# 430     2    99     0     0     0  22.2  0.108   23         0
# ..    ...   ...   ...   ...   ...   ...    ...  ...       ...
# 211     0   147    85    54     0  42.8  0.375   24         0
# 120     0   162    76    56   100  53.2  0.759   25         1
# 57      0   100    88    60   110  46.8  0.962   31         0
# 445     0   180    78    63    14  59.4  2.420   25         1
# 579     2   197    70    99     0  34.7  0.575   62         1
#
# [768 rows x 9 columns]

# %% [markdown]
# Now let's find the 4 largest values for `"age"`

# %%
df_age = df.sort_values(["age"],ascending=True)

df_age[-4:]
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  diabetes
# 684     5   136    82     0     0   0.0  0.640   69         0
# 666     4   145    82    18     0  32.5  0.235   70         1
# 453     2   119     0     0     0  19.6  0.832   72         0
# 459     9   134    74    33    60  25.9  0.460   81         0

# %% [markdown]
# Now find the smallest 4 values for `"pedi"` and `"plas"` in reverse order (smallest to largest).

# %%
df_pedi = (df.sort_values(["pedi"],ascending=True))[:4]

df_plas = (df.sort_values(["plas"],ascending=True))[:4]

df_pedi_plas = (df.sort_values(["pedi", "plas"],ascending=True))[:4]

print(df_pedi["pedi"])

print(df_plas["plas"])

df_pedi_plas
# Out:
# 268    0.078
# 180    0.084
# 567    0.085
# 149    0.085
# Name: pedi, dtype: float64
# 75     0
# 349    0
# 342    0
# 502    0
# Name: plas, dtype: int64
#      preg  plas  pres  skin  test  mass   pedi  age  diabetes
# 268     0   102    52     0     0  25.1  0.078   21         0
# 180     6    87    80     0     0  23.2  0.084   32         0
# 149     2    90    70    17     0  27.3  0.085   22         0
# 567     6    92    62    32   126  32.0  0.085   46         0
