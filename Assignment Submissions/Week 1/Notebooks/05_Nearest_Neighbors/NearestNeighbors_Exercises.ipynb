# %% [markdown]
# # Nearest Neighbors Exercises

# %%
import numpy as np
import pandas as po
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Problem 1
#
# Consider the following simple data-set:
#
# <img src="https://github.com/BeaverWorksMedlytics2020/Data_Public/raw/master/Images/Week1/knn_notebook_example_table.png" alt="Example Table" width="600">
#
# Now consider the Sample:
#     $$X= 4, Y = 4, Z = 2$$

# %% [markdown]
# Using kNN, what is the class for this sample for $k = 1$ and $k = 3?$ Use the Eucledian metric.
#
# (YOUR ANSWER HERE)
# Class Y

# %% [markdown]
# ## Problem 2
# Earlier in the tutorial we were told that kNN depends on several factors, one of them being $k$. Consider the following datasets below, find the optimal value of $k$ that gives the highest accuracy. Visualize your data! Can you come up with some rule for getting a good idea of what $k$ is?
#
# HINT: look for a pattern/bound! Answer should be in terms of the size of the dataset $n$.

# %%
import numpy as np
import pandas as po
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Solve this problem for each of these datasets
from sklearn.datasets import load_iris
from sklearn.datasets import load_breast_cancer
from sklearn.datasets import load_wine

# Load those datasets into some easily accessible variables
# The datasets are already normalized, so that saves us some steps!
iris = load_iris()                    #iris dataset: size = 150
breast_cancer = load_breast_cancer()  #diabetes dataset: size = 569
wine = load_wine()                    #wine dataset: size 178

# This function will perfom KNN classification for a specified k
def split_train_test_dataset(dataset, k, test_size=0.2):
    """Loads and performs KNN classification on the provided dataset"""
    # Grab and split the dataset
    X_train, X_val, y_train, y_val = train_test_split(
        dataset.data, dataset.target, test_size=test_size, random_state=0)

    # Build a KNN classifier, fit it and test its predictions
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    accuracy = accuracy_score(y_val, knn.predict(X_val))
    return accuracy

# %%
# YOUR CODE HERE
iris_accuracies = []
k_values = range(1, 40)

print("\niris")
for k in k_values:
  accuracy = split_train_test_dataset(iris, k, test_size=0.2)
  iris_accuracies.append(accuracy)
  print(f"Validation Accuracy for k={k} is {accuracy:.1%}")

breast_cancer_accuracies = []
print("\nbreast_cancer")
for k in k_values:
  accuracy = split_train_test_dataset(breast_cancer, k, test_size=0.2)
  breast_cancer_accuracies.append(accuracy)
  print(f"Validation Accuracy for k={k} is {accuracy:.1%}")

wine_accuracies = []
print("\nwine")
for k in k_values:
  accuracy = split_train_test_dataset(wine, k, test_size=0.2)
  wine_accuracies.append(accuracy)
  print(f"Validation Accuracy for k={k} is {accuracy:.1%}")
# Out:
# iris
# Validation Accuracy for k=1 is 100.0%
# Validation Accuracy for k=2 is 96.7%
# Validation Accuracy for k=3 is 96.7%
# Validation Accuracy for k=4 is 100.0%
# Validation Accuracy for k=5 is 96.7%
# Validation Accuracy for k=6 is 100.0%
# Validation Accuracy for k=7 is 100.0%
# Validation Accuracy for k=8 is 100.0%
# Validation Accuracy for k=9 is 100.0%
# Validation Accuracy for k=10 is 100.0%
# Validation Accuracy for k=11 is 100.0%
# Validation Accuracy for k=12 is 100.0%
# Validation Accuracy for k=13 is 100.0%
# Validation Accuracy for k=14 is 100.0%
# Validation Accuracy for k=15 is 100.0%
# Validation Accuracy for k=16 is 100.0%
# Validation Accuracy for k=17 is 100.0%
# Validation Accuracy for k=18 is 100.0%
# Validation Accuracy for k=19 is 100.0%
# Validation Accuracy for k=20 is 100.0%
# Validation Accuracy for k=21 is 100.0%
# Validation Accuracy for k=22 is 100.0%
# Validation Accuracy for k=23 is 100.0%
# Validation Accuracy for k=24 is 100.0%
# Validation Accuracy for k=25 is 100.0%
# Validation Accuracy for k=26 is 96.7%
# Validation Accuracy for k=27 is 93.3%
# Validation Accuracy for k=28 is 96.7%
# Validation Accuracy for k=29 is 96.7%
# Validation Accuracy for k=30 is 96.7%
# Validation Accuracy for k=31 is 93.3%
# Validation Accuracy for k=32 is 90.0%
# Validation Accuracy for k=33 is 93.3%
# Validation Accuracy for k=34 is 96.7%
# Validation Accuracy for k=35 is 93.3%
# Validation Accuracy for k=36 is 93.3%
# Validation Accuracy for k=37 is 93.3%
# Validation Accuracy for k=38 is 93.3%
# Validation Accuracy for k=39 is 93.3%
#
# breast_cancer
# Validation Accuracy for k=1 is 91.2%
# Validation Accuracy for k=2 is 89.5%
# Validation Accuracy for k=3 is 91.2%
# Validation Accuracy for k=4 is 92.1%
# Validation Accuracy for k=5 is 93.9%
# Validation Accuracy for k=6 is 93.9%
# Validation Accuracy for k=7 is 94.7%
# Validation Accuracy for k=8 is 94.7%
# Validation Accuracy for k=9 is 96.5%
# Validation Accuracy for k=10 is 94.7%
# Validation Accuracy for k=11 is 96.5%
# Validation Accuracy for k=12 is 96.5%
# Validation Accuracy for k=13 is 96.5%
# Validation Accuracy for k=14 is 96.5%
# Validation Accuracy for k=15 is 96.5%
# Validation Accuracy for k=16 is 96.5%
# Validation Accuracy for k=17 is 96.5%
# Validation Accuracy for k=18 is 96.5%
# Validation Accuracy for k=19 is 96.5%
# Validation Accuracy for k=20 is 96.5%
# Validation Accuracy for k=21 is 96.5%
# Validation Accuracy for k=22 is 96.5%
# Validation Accuracy for k=23 is 96.5%
# Validation Accuracy for k=24 is 96.5%
# Validation Accuracy for k=25 is 96.5%
# Validation Accuracy for k=26 is 96.5%
# Validation Accuracy for k=27 is 95.6%
# Validation Accuracy for k=28 is 96.5%
# Validation Accuracy for k=29 is 95.6%
# Validation Accuracy for k=30 is 96.5%
# Validation Accuracy for k=31 is 94.7%
# Validation Accuracy for k=32 is 94.7%
# Validation Accuracy for k=33 is 94.7%
# Validation Accuracy for k=34 is 94.7%
# Validation Accuracy for k=35 is 94.7%
# Validation Accuracy for k=36 is 94.7%
# Validation Accuracy for k=37 is 94.7%
# Validation Accuracy for k=38 is 95.6%
# Validation Accuracy for k=39 is 94.7%
#
# wine
# Validation Accuracy for k=1 is 77.8%
# Validation Accuracy for k=2 is 75.0%
# Validation Accuracy for k=3 is 77.8%
# Validation Accuracy for k=4 is 75.0%
# Validation Accuracy for k=5 is 80.6%
# Validation Accuracy for k=6 is 75.0%
# Validation Accuracy for k=7 is 77.8%
# Validation Accuracy for k=8 is 69.4%
# Validation Accuracy for k=9 is 75.0%
# Validation Accuracy for k=10 is 72.2%
# Validation Accuracy for k=11 is 72.2%
# Validation Accuracy for k=12 is 69.4%
# Validation Accuracy for k=13 is 75.0%
# Validation Accuracy for k=14 is 72.2%
# Validation Accuracy for k=15 is 72.2%
# Validation Accuracy for k=16 is 75.0%
# Validation Accuracy for k=17 is 77.8%
# Validation Accuracy for k=18 is 75.0%
# Validation Accuracy for k=19 is 77.8%
# Validation Accuracy for k=20 is 77.8%
# Validation Accuracy for k=21 is 75.0%
# Validation Accuracy for k=22 is 75.0%
# Validation Accuracy for k=23 is 75.0%
# Validation Accuracy for k=24 is 75.0%
# Validation Accuracy for k=25 is 75.0%
# Validation Accuracy for k=26 is 75.0%
# Validation Accuracy for k=27 is 75.0%
# Validation Accuracy for k=28 is 75.0%
# Validation Accuracy for k=29 is 75.0%
# Validation Accuracy for k=30 is 75.0%
# Validation Accuracy for k=31 is 75.0%
# Validation Accuracy for k=32 is 75.0%
# Validation Accuracy for k=33 is 75.0%
# Validation Accuracy for k=34 is 75.0%
# Validation Accuracy for k=35 is 75.0%
# Validation Accuracy for k=36 is 75.0%
# Validation Accuracy for k=37 is 75.0%
# Validation Accuracy for k=38 is 75.0%
# Validation Accuracy for k=39 is 75.0%

# %% [markdown]
# Write a single mathematical expression describing the relationship you found between $n$ (the size of the dataset) and $k$ (the number of datapoints used to classify each validation datum).

# %% [markdown]
# (YOUR ANSWER HERE)
#
# *   k=0.02n (approx - diff datasets have slight variations on ideal k in terms of n)

# %% [markdown]
# ## Problem 3
# Now, we will **be writing our k-NNA**. Recall that we said a kNN is comprised of a predictions and using those predictions to classify the data. Here we will try to mimic sklearn's kNN methods. We will be using the Pima diabetes dataset.

# %% [markdown]
# ### Loading and splitting data

# %%
import pandas as pd

url = "https://github.com/BeaverWorksMedlytics2020/Data_Public/raw/master/NotebookExampleData/Week1/diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = pd.read_csv(url, names=names)

# Dropping NaN rows
invalid = ['plas', 'pres', 'skin', 'test', 'mass']

for i in invalid:
    data[i].replace(to_replace=0, value=np.nan, inplace=True)

data = data.dropna(axis=0).reset_index(drop=True)
# Out:
# /tmp/ipykernel_2100/3429084323.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].replace(to_replace=0, value=np.nan, inplace=True)

# %% [markdown]
# Now, let's clearly define which columns will act as explanatory variables, and which column will be the target value, and split the dataset between your training data and testing data. Let's try an 80-20 split and use sklearn's [train_test_split](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) method (set random_state = 0 so we get the same output each time).

# %%
# Columns we will use to make predictions with (features!) feel free to play around with these
X_cols = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age']

# Column that we want to predict (the labels)
y_col = 'class'

# 80-20 train-test split of datset
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(data[X_cols], data[y_col], test_size=test_size, random_state=0)

# Further split X and y of training into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=test_size, random_state=0)

print('There are {} training samples with {} features and {} associated classification labels'.format(*X_train.shape, *y_train.shape))
print('There are {} validation samples with {} features and {} associated classification labels'.format(*X_val.shape, *y_val.shape))
print('There are {} test samples with {} features and {} associated classification labels'.format(*X_test.shape, *y_test.shape))
# Out:
# There are 250 training samples with 8 features and 250 associated classification labels
# There are 63 validation samples with 8 features and 63 associated classification labels
# There are 79 test samples with 8 features and 79 associated classification labels

# %% [markdown]
# ### Normalizing Data
#
# Let's not forget to normalize the data! We'll use sklearn's StandardScaler normalization like we did before to normalize the training **and** validation/data.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

for i in list(X_train):
    feature_data_train = X_train[i].values.reshape(-1, 1)
    scaler.fit(feature_data_train)
    X_train[i] = scaler.transform(feature_data_train)

for j in list(X_test):
    feature_data_test = X_test[j].values.reshape(-1, 1)
    scaler.fit(feature_data_test)
    X_test[j] = scaler.transform(feature_data_test)

for k in list(X_val):
    feature_data_val = X_val[k].values.reshape(-1, 1)
    scaler.fit(feature_data_val)
    X_val[k] = scaler.transform(feature_data_val)

# %% [markdown]
# ### Writing your kNN
#
# Now for the fun part! Fill in the 3 following methods, euclidean_dist(), predict(), and knn().
#
# The predict method that we'll make below needs to:
# 1. Compute the euclidean distance between the “new” observation and all the data points in the training set.
# 2. Assign the corresponding label to the observation
# 3. Select the k nearest ones and perform a "majority vote"

# %%
# Euclidean distance function from tutorial
def euclidean_dist(datum1, datum2):
    inner_val = 0.0

    for g in range(datum1.shape[0]):
        inner_val += (datum1[g]- datum2[g]) ** 2

    distance = np.sqrt(inner_val)
    return(distance)

# %%
from collections import Counter

def predict(x_training, y_training, x_test_sample, k):



    # YOUR CODE HERE
    #read and append using helper method prior
    distances = []
    for i in range(len(x_training)):
        temp_training_sample = x_training.iloc[i].values
        distance = euclidean_dist(x_test_sample, temp_training_sample)
        distances.append((distance, y_training.iloc[i]))

    # distance sort
    distances.sort(key=lambda x: x[0])
    k_nearest = distances[0:k]

    # label of kNN
    k_nearest_labels = [item[1] for item in k_nearest]

    # majority vote
    most_common = Counter(k_nearest_labels).most_common(1)
    return most_common[0][0]

# %%
def knn(x_training, y_training, x_testing, k):

    predictions = []
    for i in range(len(x_testing)):
        x_test_sample = x_testing.iloc[i].values
        temp = predict(x_training, y_training, x_test_sample, k)
        predictions.append(temp)
    return predictions

# %% [markdown]
# When done, test your code by running the methods here!

# %%
from sklearn.metrics import accuracy_score
import time

start = time.time()
predictions_slow = knn(X_train, y_train, X_val, k=5)

print('Took {} seconds'.format(time.time() - start))
print("Validation Accuracy is ", accuracy_score(y_val,predictions_slow)*100)
# Out:
# Took 0.8526999950408936 seconds
# Validation Accuracy is  80.95238095238095

# %% [markdown]
# Check sklearn's predictions on validation data from the tutorial notebook and make sure they match yours. Sklearn is faster, but you should get the same answers.
