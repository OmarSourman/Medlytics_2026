# %% [markdown]
# # Neural Network Exercise
#
# In this Exercise Notebook you will be building your own artificial neural network and seeing how adding different types of layers can affect the validation/testing accuracy. This is based off of the Simple Neural Network with Keras tutorial, so you can reference that for further explanations as well.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# %%
os.system('wget https://raw.githubusercontent.com/BeaverWorksMedlytics2020/Data_Public/master/NotebookExampleData/Week2/spoken_digit_manual_features.csv')
# Out:
# 0

# %% [markdown]
# ## Load Training Data and Pre-processed Features
#
# Your goal is to build a neural network that learns to classify which of the 5 speakers is recorded in a signal sample. Your prediction will be based off of features we've already pre-extracted for you and put into this CSV: spectral centroid `SC`, spectral flatness `SF`, and maximum frequency `MF`.

# %%
# Load csv containing raw data, labels, and pre-processed features
spoken_df = pd.read_csv('spoken_digit_manual_features.csv', index_col = 0)
print(spoken_df.head(10))
print('\n')

# Set speakers
speakers = set(spoken_df['speaker'])
print(f'There are {len(speakers)} unique speakers in the dataset')
# Out:
#                 file  digit   speaker  trial           SC        SF  \
# 0   5_yweweler_8.wav      5  yweweler      8  1029.497959  0.397336
# 1    3_george_49.wav      3    george      4  1881.296834  0.387050
# 2  9_yweweler_44.wav      9  yweweler      4  1093.951856  0.394981
# 3  8_yweweler_33.wav      8  yweweler      3  1409.543285  0.487496
# 4      7_theo_34.wav      7      theo      3   887.361601  0.396825
# 5   1_jackson_45.wav      1   jackson      4  1007.568129  0.324100
# 6  6_yweweler_18.wav      6  yweweler      1  1286.701352  0.498813
# 7    9_george_35.wav      9    george      3  1405.092061  0.353083
# 8   9_jackson_32.wav      9   jackson      3  1172.899961  0.477907
# 9    8_george_26.wav      8    george      2  1959.977577  0.462901
#
#            MF
# 0  745.878340
# 1  323.943662
# 2  244.648318
# 3  392.350401
# 4  130.640309
# 5  216.306156
# 6  400.715564
# 7  447.239693
# 8  114.892780
# 9  320.537966
#
#
# There are 5 unique speakers in the dataset

# %% [markdown]
# Converting labels to "onehot" vectors:

# %%
# Make dictionary to convert from speaker names to indices
name2int_dict = {name: ind for (ind, name) in enumerate(set(spoken_df['speaker']))}

y_labels = spoken_df['speaker']
# Set y_labels to be indices of speaker
y_labels = [name2int_dict[name] for name in y_labels]

# %% [markdown]
# Standardize data and split into train, validation, and test sets:

# %%
# Downselect to only the 3 columns of the dataset we are learning from, aka the features
X_data = spoken_df[['SC', 'SF', 'MF']].to_numpy()

# Decide how large to make validation and test sets
n_val = 250
n_test = 250

# Shuffle data before partitioning
X_data, y_labels = shuffle(X_data, y_labels, random_state = 25)

# Partition
X_data_test, y_labels_test = X_data[:n_test,:], y_labels[:n_test]
X_data_val, y_labels_val = X_data[n_test:n_test+n_val,:], y_labels[n_test:n_test+n_val]
X_data_train, y_labels_train = X_data[n_test+n_val:,:], y_labels[n_test+n_val:]

# Scale data
scaler = StandardScaler()
X_data_train=scaler.fit_transform(X_data_train)
X_data_val = scaler.transform(X_data_val)
X_data_test = scaler.transform(X_data_test)

# Convert labels to onehot
y_labels_train = tf.keras.utils.to_categorical(y_labels_train, 5)
y_labels_val =  tf.keras.utils.to_categorical(y_labels_val, 5)
y_labels_test =  tf.keras.utils.to_categorical(y_labels_test, 5)

training_set = tf.data.Dataset.from_tensor_slices((X_data_train, y_labels_train))

# %% [markdown]
# ## Additional Layers
#
# Before you get to writing your own neural network we'll show you some examples of additional layers you can potetially add that we didn't go over in the tutorial. After reading over our explanations/example code and going through documentation you'll be testing some of these out by putting together a neural network yourself.

# %% [markdown]
# ### Dropout Layers
#
# Dropout layers randomly omit, or drop, some elements of the output vector from the layer, which helps prevent overfitting and can improve the generalization of your neural network. The dropout rate can be any number between 0 and 1.
#
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout
#
# ```python
# # Example
# d_r = 0.6
# tf.keras.layers.Dropout(rate=d_r)
# ```

# %% [markdown]
# ### Pooling Layers
#
# A pooling layer reduces dimensionality (reducing the size of each feature map) and "compresses" information by combining several output elements. Two common functions used for pooling are:
# - Average pooling: calculating the average value for each patch on the feature map
# - Max pooling: calculating the maximum value for each patch of the feature map
#
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool1D
#
# ```python
# # Example
# tf.keras.layers.MaxPool1D(pool_size=1)
# ```

# %% [markdown]
# ### Activation Layers/Functions
#
# An activation function looks at each "neuron" in your neural network and determines whether it should be activated (fired) or not, based on the relevancy of the neuron's input to the model’s predictions. Some different activation functions you could look at are:
# - softmax https://www.tensorflow.org/api_docs/python/tf/keras/layers/Softmax
# - sigmoid https://www.tensorflow.org/api_docs/python/tf/keras/activations/sigmoid
# - softplus https://www.tensorflow.org/api_docs/python/tf/keras/activations/softplus
# - relu https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU
#
# ```python
# # Example
# tf.keras.layers.Softmax()
# ```

# %% [markdown]
# ### Optimation Functions
#
# Optimation functions
# - Adam https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam
#   - Adam is computationally efficient, has little memory requirement, and is well suited for problems that are large in terms of data/parameter.
# - Adagrad https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adagrad
#   - Adagrad is an optimizer that is best used for sparse data. Some of its benefits are that it converges more quickly and doesn't need manual adjustment of the hyperparameter "learning rate".
# - SGD https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD
#   - SGD is a stochastic gradient descent and momentum optimizer. SGD essentially helps gradient vectors move down loss functions towards the minimum point, leading to faster "converging".
# - RMSprop https://keras.io/api/optimizers/rmsprop/
#   - As you may already know, the learning rate regulates how much the model
# can change based on the estimated error (which occurs every time the model's weights are updated). Instead of treating the learning rate as a hyperparamter, RMSprop is an optimization technique that uses relies on a changing, adaptive learning rate.
#
# ```python
# # Example code
# l_r = .001
# tf.keras.optimizers.SGD(learning_rate=l_r)
# ```

# %% [markdown]
# ## Putting Together Your Neural Network
#
# Now you will experiment with adding different layers to your neural network. We've added some guiding comments to give you a place to start and test out, but we also strongly encourage you to go through all the documetation and do some googling as well!

# %%
# Once you've gone through all the tests play around with these rate alues to see if you can increase your accuracy
l_r = .001
d_r = 0.6

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(8, input_shape=(3,)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Test 1

# %%
# Run this cell as it is
# model.add(tf.keras.layers.Dense(8))
# model.add(tf.keras.layers.Dense(8))

# # output dimension needs to be number of classes in order for each to get a score
# model.add(tf.keras.layers.Dense(5))

# Now skip down to the section that compiles and trains your model and run those cells.
# Check the pseudo-test accuracy and see how well the bare minimum performed.

# %% [markdown]
# ### Test 2

# %%
# # Add activation layer here
# model.add(tf.keras.layers.Dense(8))
# model.add(tf.keras.layers.Activation('relu'))
# # Add activation layer here
# model.add(tf.keras.layers.Dense(8))
# model.add(tf.keras.layers.Activation('relu'))
# # Add activation layer here

# # output dimension needs to be number of classes in order for each to get a score
# model.add(tf.keras.layers.Dense(5))
# model.add(tf.keras.layers.Activation('softmax'))

# Now skip down to the section that compiles and trains your model and re-run those cells.
# What do you notice about the testing/Validation accuracy after Test 2 in comparison to Test 1?

# %% [markdown]
# ### Test 3

# %%
# Add activation layer here
model.add(tf.keras.layers.Dense(128))
model.add(tf.keras.layers.Activation('relu'))
# Add activation layer here
model.add(tf.keras.layers.Dense(64))
model.add(tf.keras.layers.Activation('relu'))
# Add activation layer here
model.add(tf.keras.layers.Dense(16))
model.add(tf.keras.layers.Activation('relu'))

# output dimension needs to be number of classes in order for each to get a score
model.add(tf.keras.layers.Dense(5))
model.add(tf.keras.layers.Activation('softmax'))

# Add dropout layer here
# model.add(tf.keras.layers.Dropout(rate=d_r))

# Now skip down to the section that compiles and trains your model and re-run those cells.
# What do you notice about the testing/Validation accuracy after Test 2 in comparison to Test 1 & 2?

# %% [markdown]
# ### Test 4
#
# Now go back down to the cell where you compiled your model, and this time change the optimizer. It's been set to Adam by default but as we showed you above, there are other functions that you can test out.

# %% [markdown]
# ## Compiling and Training Your Model

# %%
model.compile(loss = tf.keras.losses.categorical_crossentropy,
              optimizer = tf.keras.optimizers.Adam(learning_rate=l_r),
              metrics = ['accuracy'])

# %% [markdown]
# Fit Model to Data, Specify Number of Epochs and Batch Size:

# %%
EPOCHS = 100
batch_size = 100

training_set = training_set.batch(batch_size) #set batch size

for epoch in range(EPOCHS):
    for signals, labels in training_set:
        tr_loss, tr_accuracy = model.train_on_batch(signals, labels)
    val_loss, val_accuracy = model.evaluate(X_data_val, y_labels_val)
    print(('Epoch #%d\t Training Loss: %.2f\tTraining Accuracy: %.2f\t'
         'Validation Loss: %.2f\tValidation Accuracy: %.2f')
         % (epoch + 1, tr_loss, tr_accuracy,
         val_loss, val_accuracy))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2680 - loss: 1.4676
# Epoch #1	 Training Loss: 1.54	Training Accuracy: 0.29	Validation Loss: 1.47	Validation Accuracy: 0.27
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3800 - loss: 1.3693
# Epoch #2	 Training Loss: 1.42	Training Accuracy: 0.34	Validation Loss: 1.37	Validation Accuracy: 0.38
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4920 - loss: 1.2363
# Epoch #3	 Training Loss: 1.30	Training Accuracy: 0.45	Validation Loss: 1.24	Validation Accuracy: 0.49
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5320 - loss: 1.1543
# Epoch #4	 Training Loss: 1.19	Training Accuracy: 0.52	Validation Loss: 1.15	Validation Accuracy: 0.53
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5360 - loss: 1.1160
# Epoch #5	 Training Loss: 1.12	Training Accuracy: 0.54	Validation Loss: 1.12	Validation Accuracy: 0.54
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5400 - loss: 1.0940
# Epoch #6	 Training Loss: 1.09	Training Accuracy: 0.55	Validation Loss: 1.09	Validation Accuracy: 0.54
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5560 - loss: 1.0736
# Epoch #7	 Training Loss: 1.07	Training Accuracy: 0.56	Validation Loss: 1.07	Validation Accuracy: 0.56
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5560 - loss: 1.0574
# Epoch #8	 Training Loss: 1.05	Training Accuracy: 0.56	Validation Loss: 1.06	Validation Accuracy: 0.56
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5600 - loss: 1.0447
# Epoch #9	 Training Loss: 1.04	Training Accuracy: 0.56	Validation Loss: 1.04	Validation Accuracy: 0.56
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5640 - loss: 1.0315
# Epoch #10	 Training Loss: 1.03	Training Accuracy: 0.56	Validation Loss: 1.03	Validation Accuracy: 0.56
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5640 - loss: 1.0225
# Epoch #11	 Training Loss: 1.02	Training Accuracy: 0.57	Validation Loss: 1.02	Validation Accuracy: 0.56
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5640 - loss: 1.0121
# Epoch #12	 Training Loss: 1.01	Training Accuracy: 0.57	Validation Loss: 1.01	Validation Accuracy: 0.56
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5760 - loss: 1.0061
# Epoch #13	 Training Loss: 1.00	Training Accuracy: 0.57	Validation Loss: 1.01	Validation Accuracy: 0.58
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5800 - loss: 0.9993
# Epoch #14	 Training Loss: 1.00	Training Accuracy: 0.58	Validation Loss: 1.00	Validation Accuracy: 0.58
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5760 - loss: 0.9927
# Epoch #15	 Training Loss: 0.99	Training Accuracy: 0.58	Validation Loss: 0.99	Validation Accuracy: 0.58
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5680 - loss: 0.9857
# Epoch #16	 Training Loss: 0.98	Training Accuracy: 0.58	Validation Loss: 0.99	Validation Accuracy: 0.57
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5680 - loss: 0.9808
# Epoch #17	 Training Loss: 0.97	Training Accuracy: 0.59	Validation Loss: 0.98	Validation Accuracy: 0.57
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5800 - loss: 0.9755
# Epoch #18	 Training Loss: 0.97	Training Accuracy: 0.59	Validation Loss: 0.98	Validation Accuracy: 0.58
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5800 - loss: 0.9701
# Epoch #19	 Training Loss: 0.96	Training Accuracy: 0.59	Validation Loss: 0.97	Validation Accuracy: 0.58
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5880 - loss: 0.9652
# Epoch #20	 Training Loss: 0.96	Training Accuracy: 0.59	Validation Loss: 0.97	Validation Accuracy: 0.59
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5960 - loss: 0.9608
# Epoch #21	 Training Loss: 0.95	Training Accuracy: 0.59	Validation Loss: 0.96	Validation Accuracy: 0.60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6000 - loss: 0.9566
# Epoch #22	 Training Loss: 0.95	Training Accuracy: 0.60	Validation Loss: 0.96	Validation Accuracy: 0.60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6080 - loss: 0.9524
# Epoch #23	 Training Loss: 0.94	Training Accuracy: 0.60	Validation Loss: 0.95	Validation Accuracy: 0.61
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6120 - loss: 0.9482
# Epoch #24	 Training Loss: 0.94	Training Accuracy: 0.61	Validation Loss: 0.95	Validation Accuracy: 0.61
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6160 - loss: 0.9451
# Epoch #25	 Training Loss: 0.93	Training Accuracy: 0.61	Validation Loss: 0.95	Validation Accuracy: 0.62
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6160 - loss: 0.9405
# Epoch #26	 Training Loss: 0.93	Training Accuracy: 0.62	Validation Loss: 0.94	Validation Accuracy: 0.62
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6120 - loss: 0.9388
# Epoch #27	 Training Loss: 0.92	Training Accuracy: 0.62	Validation Loss: 0.94	Validation Accuracy: 0.61
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6160 - loss: 0.9349
# Epoch #28	 Training Loss: 0.92	Training Accuracy: 0.62	Validation Loss: 0.93	Validation Accuracy: 0.62
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6200 - loss: 0.9315
# Epoch #29	 Training Loss: 0.91	Training Accuracy: 0.62	Validation Loss: 0.93	Validation Accuracy: 0.62
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6160 - loss: 0.9268
# Epoch #30	 Training Loss: 0.91	Training Accuracy: 0.62	Validation Loss: 0.93	Validation Accuracy: 0.62
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6120 - loss: 0.9245
# Epoch #31	 Training Loss: 0.91	Training Accuracy: 0.62	Validation Loss: 0.92	Validation Accuracy: 0.61
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6160 - loss: 0.9196
# Epoch #32	 Training Loss: 0.90	Training Accuracy: 0.63	Validation Loss: 0.92	Validation Accuracy: 0.62
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6160 - loss: 0.9165
# Epoch #33	 Training Loss: 0.90	Training Accuracy: 0.63	Validation Loss: 0.92	Validation Accuracy: 0.62
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6200 - loss: 0.9132
# Epoch #34	 Training Loss: 0.89	Training Accuracy: 0.63	Validation Loss: 0.91	Validation Accuracy: 0.62
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6280 - loss: 0.9113
# Epoch #35	 Training Loss: 0.89	Training Accuracy: 0.63	Validation Loss: 0.91	Validation Accuracy: 0.63
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6240 - loss: 0.9088
# Epoch #36	 Training Loss: 0.89	Training Accuracy: 0.64	Validation Loss: 0.91	Validation Accuracy: 0.62
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6240 - loss: 0.9062
# Epoch #37	 Training Loss: 0.88	Training Accuracy: 0.64	Validation Loss: 0.91	Validation Accuracy: 0.62
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6280 - loss: 0.9052
# Epoch #38	 Training Loss: 0.88	Training Accuracy: 0.64	Validation Loss: 0.91	Validation Accuracy: 0.63
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6400 - loss: 0.9030
# Epoch #39	 Training Loss: 0.88	Training Accuracy: 0.64	Validation Loss: 0.90	Validation Accuracy: 0.64
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6440 - loss: 0.9005
# Epoch #40	 Training Loss: 0.88	Training Accuracy: 0.65	Validation Loss: 0.90	Validation Accuracy: 0.64
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6440 - loss: 0.8982
# Epoch #41	 Training Loss: 0.87	Training Accuracy: 0.65	Validation Loss: 0.90	Validation Accuracy: 0.64
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6520 - loss: 0.8955
# Epoch #42	 Training Loss: 0.87	Training Accuracy: 0.65	Validation Loss: 0.90	Validation Accuracy: 0.65
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6520 - loss: 0.8920
# Epoch #43	 Training Loss: 0.87	Training Accuracy: 0.66	Validation Loss: 0.89	Validation Accuracy: 0.65
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6480 - loss: 0.8913
# Epoch #44	 Training Loss: 0.86	Training Accuracy: 0.66	Validation Loss: 0.89	Validation Accuracy: 0.65
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6440 - loss: 0.8872
# Epoch #45	 Training Loss: 0.86	Training Accuracy: 0.66	Validation Loss: 0.89	Validation Accuracy: 0.64
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6520 - loss: 0.8856
# Epoch #46	 Training Loss: 0.86	Training Accuracy: 0.66	Validation Loss: 0.89	Validation Accuracy: 0.65
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6480 - loss: 0.8836
# Epoch #47	 Training Loss: 0.86	Training Accuracy: 0.66	Validation Loss: 0.88	Validation Accuracy: 0.65
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6480 - loss: 0.8806
# Epoch #48	 Training Loss: 0.85	Training Accuracy: 0.66	Validation Loss: 0.88	Validation Accuracy: 0.65
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6520 - loss: 0.8801
# Epoch #49	 Training Loss: 0.85	Training Accuracy: 0.66	Validation Loss: 0.88	Validation Accuracy: 0.65
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6560 - loss: 0.8765
# Epoch #50	 Training Loss: 0.85	Training Accuracy: 0.66	Validation Loss: 0.88	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6520 - loss: 0.8745
# Epoch #51	 Training Loss: 0.85	Training Accuracy: 0.66	Validation Loss: 0.87	Validation Accuracy: 0.65
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6560 - loss: 0.8727
# Epoch #52	 Training Loss: 0.84	Training Accuracy: 0.66	Validation Loss: 0.87	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6560 - loss: 0.8703
# Epoch #53	 Training Loss: 0.84	Training Accuracy: 0.66	Validation Loss: 0.87	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6560 - loss: 0.8682
# Epoch #54	 Training Loss: 0.84	Training Accuracy: 0.66	Validation Loss: 0.87	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6520 - loss: 0.8667
# Epoch #55	 Training Loss: 0.84	Training Accuracy: 0.66	Validation Loss: 0.87	Validation Accuracy: 0.65
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6600 - loss: 0.8627
# Epoch #56	 Training Loss: 0.84	Training Accuracy: 0.67	Validation Loss: 0.86	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6560 - loss: 0.8625
# Epoch #57	 Training Loss: 0.83	Training Accuracy: 0.67	Validation Loss: 0.86	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6520 - loss: 0.8592
# Epoch #58	 Training Loss: 0.83	Training Accuracy: 0.67	Validation Loss: 0.86	Validation Accuracy: 0.65
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6560 - loss: 0.8583
# Epoch #59	 Training Loss: 0.83	Training Accuracy: 0.67	Validation Loss: 0.86	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6680 - loss: 0.8550
# Epoch #60	 Training Loss: 0.83	Training Accuracy: 0.67	Validation Loss: 0.85	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6600 - loss: 0.8550
# Epoch #61	 Training Loss: 0.83	Training Accuracy: 0.67	Validation Loss: 0.86	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6640 - loss: 0.8518
# Epoch #62	 Training Loss: 0.82	Training Accuracy: 0.67	Validation Loss: 0.85	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6640 - loss: 0.8502
# Epoch #63	 Training Loss: 0.82	Training Accuracy: 0.67	Validation Loss: 0.85	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6640 - loss: 0.8473
# Epoch #64	 Training Loss: 0.82	Training Accuracy: 0.67	Validation Loss: 0.85	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6720 - loss: 0.8463
# Epoch #65	 Training Loss: 0.82	Training Accuracy: 0.67	Validation Loss: 0.85	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6680 - loss: 0.8436
# Epoch #66	 Training Loss: 0.82	Training Accuracy: 0.68	Validation Loss: 0.84	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6680 - loss: 0.8430
# Epoch #67	 Training Loss: 0.81	Training Accuracy: 0.68	Validation Loss: 0.84	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6680 - loss: 0.8418
# Epoch #68	 Training Loss: 0.81	Training Accuracy: 0.68	Validation Loss: 0.84	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6720 - loss: 0.8391
# Epoch #69	 Training Loss: 0.81	Training Accuracy: 0.68	Validation Loss: 0.84	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6720 - loss: 0.8396
# Epoch #70	 Training Loss: 0.81	Training Accuracy: 0.68	Validation Loss: 0.84	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6720 - loss: 0.8362
# Epoch #71	 Training Loss: 0.81	Training Accuracy: 0.68	Validation Loss: 0.84	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6640 - loss: 0.8368
# Epoch #72	 Training Loss: 0.81	Training Accuracy: 0.68	Validation Loss: 0.84	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6680 - loss: 0.8337
# Epoch #73	 Training Loss: 0.81	Training Accuracy: 0.68	Validation Loss: 0.83	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6720 - loss: 0.8334
# Epoch #74	 Training Loss: 0.80	Training Accuracy: 0.68	Validation Loss: 0.83	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6680 - loss: 0.8333
# Epoch #75	 Training Loss: 0.80	Training Accuracy: 0.68	Validation Loss: 0.83	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6640 - loss: 0.8314
# Epoch #76	 Training Loss: 0.80	Training Accuracy: 0.68	Validation Loss: 0.83	Validation Accuracy: 0.66
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6720 - loss: 0.8315
# Epoch #77	 Training Loss: 0.80	Training Accuracy: 0.68	Validation Loss: 0.83	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6760 - loss: 0.8300
# Epoch #78	 Training Loss: 0.80	Training Accuracy: 0.68	Validation Loss: 0.83	Validation Accuracy: 0.68
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6720 - loss: 0.8299
# Epoch #79	 Training Loss: 0.80	Training Accuracy: 0.69	Validation Loss: 0.83	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6800 - loss: 0.8284
# Epoch #80	 Training Loss: 0.80	Training Accuracy: 0.69	Validation Loss: 0.83	Validation Accuracy: 0.68
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6800 - loss: 0.8268
# Epoch #81	 Training Loss: 0.79	Training Accuracy: 0.69	Validation Loss: 0.83	Validation Accuracy: 0.68
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6800 - loss: 0.8247
# Epoch #82	 Training Loss: 0.79	Training Accuracy: 0.69	Validation Loss: 0.82	Validation Accuracy: 0.68
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6800 - loss: 0.8259
# Epoch #83	 Training Loss: 0.79	Training Accuracy: 0.69	Validation Loss: 0.83	Validation Accuracy: 0.68
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6720 - loss: 0.8250
# Epoch #84	 Training Loss: 0.79	Training Accuracy: 0.69	Validation Loss: 0.83	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6680 - loss: 0.8249
# Epoch #85	 Training Loss: 0.79	Training Accuracy: 0.69	Validation Loss: 0.82	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6720 - loss: 0.8230
# Epoch #86	 Training Loss: 0.79	Training Accuracy: 0.69	Validation Loss: 0.82	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6720 - loss: 0.8246
# Epoch #87	 Training Loss: 0.79	Training Accuracy: 0.69	Validation Loss: 0.82	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6680 - loss: 0.8210
# Epoch #88	 Training Loss: 0.79	Training Accuracy: 0.69	Validation Loss: 0.82	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6720 - loss: 0.8228
# Epoch #89	 Training Loss: 0.78	Training Accuracy: 0.69	Validation Loss: 0.82	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6680 - loss: 0.8190
# Epoch #90	 Training Loss: 0.78	Training Accuracy: 0.69	Validation Loss: 0.82	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6720 - loss: 0.8217
# Epoch #91	 Training Loss: 0.78	Training Accuracy: 0.69	Validation Loss: 0.82	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6680 - loss: 0.8191
# Epoch #92	 Training Loss: 0.78	Training Accuracy: 0.69	Validation Loss: 0.82	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6680 - loss: 0.8197
# Epoch #93	 Training Loss: 0.78	Training Accuracy: 0.69	Validation Loss: 0.82	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6800 - loss: 0.8179
# Epoch #94	 Training Loss: 0.78	Training Accuracy: 0.69	Validation Loss: 0.82	Validation Accuracy: 0.68
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6800 - loss: 0.8192
# Epoch #95	 Training Loss: 0.78	Training Accuracy: 0.70	Validation Loss: 0.82	Validation Accuracy: 0.68
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6720 - loss: 0.8175
# Epoch #96	 Training Loss: 0.78	Training Accuracy: 0.70	Validation Loss: 0.82	Validation Accuracy: 0.67
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6760 - loss: 0.8178
# Epoch #97	 Training Loss: 0.77	Training Accuracy: 0.70	Validation Loss: 0.82	Validation Accuracy: 0.68
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6760 - loss: 0.8173
# Epoch #98	 Training Loss: 0.77	Training Accuracy: 0.70	Validation Loss: 0.82	Validation Accuracy: 0.68
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6760 - loss: 0.8145
# Epoch #99	 Training Loss: 0.77	Training Accuracy: 0.70	Validation Loss: 0.81	Validation Accuracy: 0.68
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6840 - loss: 0.8141
# Epoch #100	 Training Loss: 0.77	Training Accuracy: 0.70	Validation Loss: 0.81	Validation Accuracy: 0.68

# %%
#Check Performance on Test Set
test_loss, test_accuracy = model.evaluate(X_data_test, y_labels_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6920 - loss: 0.8405

# %% [markdown]
# Now modify the existing model even more, and try to find the highest and appropriate testing and validation accuracy!
